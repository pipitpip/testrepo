# %%
import pandas as pd

data = pd.read_csv("german_credit_data.csv")

# %%
data
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male    2     own             NaN           little           1169
# 1     22  female    2     own          little         moderate           5951
# 2     49    male    1     own          little              NaN           2096
# 3     45    male    2    free          little           little           7882
# 4     53    male    2    free          little           little           4870
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   31  female    1     own          little              NaN           1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little              NaN            804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
# ...

# %%
data [(data["Sex"]=="male") & (data["Age"]>50)]
# Out:
#      Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     67  male    2     own             NaN           little           1169
# 4     53  male    2    free          little           little           4870
# 6     53  male    2     own      quite rich              NaN           2835
# 8     61  male    1     own            rich              NaN           3059
# 13    60  male    1     own          little           little           1199
# ..   ...   ...  ...     ...             ...              ...            ...
# 848   59  male    2     own          little           little           1364
# 849   57  male    1     own          little           little            709
# 917   68  male    3     own          little           little          14896
# 924   55  male    2     own          little           little           6872
# 928   58  male    2     own             NaN              NaN           1867
#
#      Duration              Purpose  Risk
# ...

# %%
data [(data["Sex"]=="male") & (data["Age"]>50) & (data["Duration"]>20)]
# Out:
#      Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 4     53  male    2    free          little           little           4870
# 6     53  male    2     own      quite rich              NaN           2835
# 13    60  male    1     own          little           little           1199
# 16    53  male    2     own             NaN              NaN           2424
# 29    63  male    2     own          little           little           6836
# 54    57  male    2    free          little         moderate           2225
# 62    61  male    3    free          little         moderate           1953
# 95    58  male    2    rent          little         moderate          15945
# 179   65  male    2     own          little           little            571
# 190   54  male    3     own            rich              NaN           4591
# 213   66  male    3     own          little             rich           1908
# ...

# %%
data.iloc[[5,6,12],[1,6]]
# Out:
#        Sex  Credit amount
# 5     male           9055
# 6     male           2835
# 12  female           1567

# %%
data.loc [[5,6,12],["Sex", "Credit amount"]]
# Out:
#        Sex  Credit amount
# 5     male           9055
# 6     male           2835
# 12  female           1567

# %%
data.loc [30:50,"Housing":"Credit amount"]
# Out:
#    Housing Saving accounts Checking account  Credit amount
# 30     own            rich         moderate           1913
# 31     own          little           little           4020
# 32     own        moderate         moderate           5866
# 33    rent             NaN              NaN           1264
# 34     own          little             rich           1474
# 35     own          little         moderate           4746
# 36    free          little              NaN           6110
# 37     own          little             rich           2100
# 38     own          little             rich           1225
# 39     own          little         moderate            458
# 40     own      quite rich              NaN           2333
# 41     own      quite rich         moderate           1158
# 42     own          little         moderate           6204
# 43    rent        moderate           little           6187
# 44    free          little           little           6143
# ...
